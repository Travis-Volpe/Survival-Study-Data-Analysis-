# %%
import pandas as pd
import numpy as np

#import category_encoders as ce
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

from sklearn.model_selection import train_test_split, cross_val_score

from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor

from sklearn import metrics
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, matthews_corrcoef, classification_report, roc_curve

# %%
# Import and load data
ss_data_path = r'E:/SurvivalStudyDataAnalysis/Data/SS_Data_sty.csv'
ss_pre = pd.read_csv(ss_data_path, sep=',')
ss_pre
# Out:
#        FID   CT_Tag_ID            Date_Ptd           Cultivar  \
# 0        0  CT12134016   4/11/2015 0:00:00
# 1        1  CT12124044   4/22/2015 0:00:00
# 2        2  CT12124063    4/6/2015 0:00:00
# 3        3  CT12131001   5/14/2015 0:00:00
# 4        4  CT12133007   4/11/2015 0:00:00
# 5        5  CT13219082  11/18/2015 0:00:00
# 6        6  CT13221059   3/31/2015 0:00:00
# 7        7  CT13221066   5/13/2015 0:00:00
# 8        8  CT13221067   4/11/2015 0:00:00
# 9        9  CT13221069   4/22/2015 0:00:00
# 10      10  CT13221070   4/16/2015 0:00:00
# 11      11  CT13221072   4/21/2015 0:00:00
# 12      12  CT13221074   4/21/2015 0:00:00
# 13      13  CT13221075   4/11/2015 0:00:00
# 14      14  CT13221086   11/3/2015 0:00:00
# 15      15  CT13223026  11/10/2015 0:00:00    American Sentry
# 16      16  CT13223034   3/31/2015 0:00:00    American Sentry
# 17      17  CT13224056  11/25/2015 0:00:00  Autumn Brilliance
# 18      18  CT13224058  11/25/2015 0:00:00  Autumn Brilliance
# ...

# %%
ss_pre.columns
# Out:
# Index(['FID', 'CT_Tag_ID', 'Date_Ptd', 'Cultivar', 'SciName', 'CmmnName',
#        'DBH', 'Program', 'EventORAdd', 'Impervious', 'DBH1', 'DBH2', 'DBH3',
#        'DBH4', 'TotalHeigh', 'Width_NS', 'Width_EW', 'PercentMis',
#        'CrownCondi', 'TreeStruct', 'SpaceType1', 'CrownBase', 'Jurisdicti',
#        'SpaceTypeD', 'Cond_18', 'SpaceType', 'Condition', 'DDOE', 'PTG_Notes',
#        'Cond_12', 'Genus', 'Species', 'StockType', 'Class_Code', 'Mntc_Condn',
#        'Season', 'Nursery', 'Condit_13', 'POINT_X', 'POINT_Y', 'Cond_17',
#        'Cond_16', 'Cond_15', 'Cond_14', 'db_jdx', 'db_year', 'db_Season',
#        'db_removed', 'db_SpaceTy', 'db_Prog', 'db_StockT', 'db_ClassCo',
#        'db_Nursery', 'db_Genus', 'db_Species', 'db_mtc', 'db_pltdbh',
#        'isAlive', 'Death_Yr', 'Death_Age', 'Age', 'Cond_Agg'],
#       dtype='object')

# %%
ss = ss_pre.drop(['FID','CT_Tag_ID', 'Date_Ptd', 'Impervious', 'DBH', 'DBH1', 'DBH2','DBH3','DBH4',  'Class_Code', 'db_pltdbh', 'Condition', 'DDOE', 'SpaceType', 'PTG_Notes', 'Genus', 'Species',
                    'StockType', 'Mntc_Condn', 'Season', 'db_ClassCo', 'db_mtc', 'db_Species', 'Nursery', 'SpaceTypeD',
                    'db_removed', 'Cond_18', 'Cond_17', 'Cond_16', 'Cond_15', 'Cond_14', 'Condit_13', 'Cond_12',
                    'Cond_Agg', 'db_year', 'Jurisdicti', 'CmmnName', 'db_SpaceTy', 'db_pltdbh', 'db_mtc', 'EventORAdd',
                    'TotalHeigh', 'Width_NS', 'Width_EW', 'PercentMis','CrownCondi', 'TreeStruct',
                  'CrownBase', 'POINT_X', 'POINT_Y'],
                  axis=1)
print(ss.dtypes)
print(ss.columns)
# Out:
# Cultivar      object
# SciName       object
# Program       object
# SpaceType1    object
# db_jdx        object
# db_Season     object
# db_Prog       object
# db_StockT     object
# db_Nursery    object
# db_Genus      object
# isAlive        int64
# Death_Yr       int64
# Death_Age      int64
# Age            int64
# dtype: object
# Index(['Cultivar', 'SciName', 'Program', 'SpaceType1', 'db_jdx', 'db_Season',
#        'db_Prog', 'db_StockT', 'db_Nursery', 'db_Genus', 'isAlive', 'Death_Yr',
#        'Death_Age', 'Age'],
#       dtype='object')

# %%
feat_cols = ['db_jdx', 'db_Season', 'SpaceType1', 'db_Prog', 'db_StockT', 
             'db_Nursery', 'SciName', 'Program'
            ]

# %%
#Get Dummy Variables

# %%
# Linear Regression Run on the Age of Trees
X = df.iloc[:, 1:200]

y = df.Age

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=1)

linreg = LinearRegression()

linreg.fit(X_train, y_train)

linreg.coef_

scores = cross_val_score(linreg, X_train, y_train, cv=200, scoring='neg_mean_squared_error')

agg = np.mean(np.sqrt(-scores))

print('Coefficents:', linreg.coef_)

print('Cross validation score:', scores)

print('RMSE:', agg)

# %%
def ols_res(df, xcols,  ycol):
    return sm.OLS(df[ycol], df[xcols]).fit().predict()

# %%
ss.SciName.value_counts().head(20)
# Out:
# Ulmus americana                    860
# Cercis canadensis                  567
# Betula nigra                       460
# Nyssa sylvatica                    314
# Liquidambar styraciflua            247
# Magnolia virginiana                241
# Acer rubrum                        218
# Magnolia grandiflora               186
# Juniperus virginiana               173
# Liriodendron tulipifera            172
# Ilex opaca                         170
# Carpinus caroliniana               165
# Cornus florida                     165
# Platanus x acerifolia              164
# Quercus bicolor                    158
# Lagerstroemia indica               139
# Prunus yedoensis                   136
# Quercus phellos                    136
# Cladrastis kentukea                133
# Amelanchier 'Autumn Brilliance'    120
# Name: SciName, dtype: int64

# %%
Ulmus_americana = ss.loc[ss['SciName'] == 'Ulmus americana']
Ulmus_grouped = Ulmus_americana.groupby(['db_jdx', 'db_Season', 'SpaceType1', 'db_Prog', 'db_StockT', 
             'db_Nursery', 'SciName', 'Program'])
Ulmus_grouped.groups
len(Ulmus_grouped)
# Out:
# 105

# %%
grouped = ss.groupby(['db_jdx', 'db_Season', 'SpaceType1', 'db_Prog', 'db_StockT', 
             'db_Nursery', 'SciName', 'Program'])
grouped.groups
len(grouped)
# Out:
# 4553

# %%
# Create groupings based on SciName, Space Type, Nursery, Program, Jurisdiction, Season, Stock Type
